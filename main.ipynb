# %%
#Import Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
#Load Dataset
import pandas as pd
df = pd.read_csv("/content/laptop_price_dataset.csv")
df.head()
# Out:
#   Company   RAM CPU    Storage     GPU Weight  Price
# 0    Dell   8GB  i5  256GB SSD   Intel  2.1kg  55000
# 1      HP   4GB  i3    1TB HDD     AMD  1.9kg  35000
# 2   Apple   8GB  i5  256GB SSD   Intel  1.3kg  95000
# 3  Lenovo  16GB  i7  512GB SSD  NVIDIA  2.3kg  85000
# 4    Asus   8GB  i5  512GB SSD   Intel  2.0kg  60000

# %%
#Convert Text Data into Numbers
le = LabelEncoder()

for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = le.fit_transform(df[column])

print(df.head())
# Out:
#    Company  RAM  CPU  Storage  GPU  Weight  Price
# 0        3    3    4        2    2       5  55000
# 1        4    2    3        0    0       3  35000
# 2        1    3    4        2    2       0  95000
# 3        5    0    5        5    3       7  85000
# 4        2    3    4        5    2       4  60000

# %%
#Separate Input and Output Data
X = df.drop("Price", axis=1)
Y = df["Price"]

# %%
#Split Dataset into Training and Testing Data
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

# %%
#Train Machine Learning Model
#use Linear Regression model
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
#Predict Laptop Price
predictions = model.predict(X_test)
print(predictions)
# Out:
# [46754.35928976 65717.78678777 53796.40985643 53231.85826664]

# %%
#Check Model Accuracy
from sklearn.metrics import mean_absolute_error
error = mean_absolute_error(Y_test, predictions)
print("Mean Absolute Error:", error)

#Lower error means better prediction
# Out:
# Mean Absolute Error: 7389.030511388801

# %%
# Actual Price vs Predicted Price
plt.figure(figsize=(6,6))
plt.scatter(Y_test, predictions)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted Laptop Price")
plt.show()

# %%
# RAM vs Price Graph
plt.figure(figsize=(6,6))
plt.scatter(df['RAM'], df['Price'])
plt.xlabel("RAM")
plt.ylabel("Price")
plt.title("RAM vs Laptop Price")
plt.show()

# %%
#Weight vs Price Graph
plt.figure(figsize=(6,6))
plt.scatter(df['Weight'], df['Price'])
plt.xlabel("Weight")
plt.ylabel("Price")
plt.title("Weight vs Laptop Price")
plt.show()
